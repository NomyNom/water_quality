# %%
import numpy as np
import pandas as pd

# %%
station_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/station.csv')
station_df.head()
# Out:
#   OrganizationIdentifier           OrganizationFormalName  \
# 0                USGS-TX  USGS Texas Water Science Center
# 1                USGS-TX  USGS Texas Water Science Center
# 2                USGS-TX  USGS Texas Water Science Center
# 3                USGS-TX  USGS Texas Water Science Center
# 4                USGS-TX  USGS Texas Water Science Center
#
#   MonitoringLocationIdentifier  \
# 0                USGS-08067074
# 1                USGS-08069500
# 2                USGS-08071330
# 3                USGS-08072050
# 4                USGS-08073600
#
#                               MonitoringLocationName  \
# 0            CWA Canal at Thompson Rd nr Baytown, TX
# 1                  W Fk San Jacinto Rv nr Humble, TX
# 2  Luce Bayou at Huffman Cleveland Rd nr Huffman, TX
# 3                      San Jacinto Rv nr Sheldon, TX
# 4            Buffalo Bayou at W Belt Dr, Houston, TX
#
#   MonitoringLocationTypeName  MonitoringLocationDescriptionText  \
# ...

# %%
bio_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/biologicalmetric.csv')
bio_df.head()
# Out:
#   OrganizationIdentifier MonitoringLocationIdentifier  \
# 0               NARS_WQX           NARS_WQX-FW08TX045
# 1               NARS_WQX           NARS_WQX-FW08TX045
# 2               NARS_WQX           NARS_WQX-FW08TX045
# 3               NARS_WQX           NARS_WQX-FW08TX045
# 4               NARSTEST           NARSTEST-FW08TX045
#
#                        IndexIdentifier IndexTypeIdentifier  \
# 0  06282008FW08TX045MMI_RF_FISH_PLNLOW  MMI_RF_FISH_PLNLOW
# 1      BENC:TX045:080628:BENT_MMI_COND       BENT_MMI_COND
# 2           BENC:TX045:080628:OE_COND2            OE_COND2
# 3             FW08TX04520080628FISHHBI                 HBI
# 4       BENC:TX045:080628:MMI_BENT_CPL        MMI_BENT_CPL
#
#   IndexTypeIdentifierContext  \
# 0                   NARS_WQX
# 1                   NARS_WQX
# 2                   NARS_WQX
# 3                   NARS_WQX
# 4                   NARSTEST
#
#                                        IndexTypeName  \
# ...

# %%
water_quality_minor_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/WaterQualityMinor_v1.csv')
water_quality_minor_df.head()
# Out:
# /var/folders/jw/plp7h3rx77nby1bttx42xypw0000gn/T/ipykernel_45660/3702369995.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   water_quality_minor_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/WaterQualityMinor_v1.csv')
#    StateWellNumber  County      Aquifer  SampleMonth  SampleDay  SampleYear  \
# 0           140601  Dallam  Rita Blanca            6         19        1989
# 1           140601  Dallam  Rita Blanca            6         19        1989
# 2           140601  Dallam  Rita Blanca            6         19        1989
# 3           140601  Dallam  Rita Blanca            6         19        1989
# 4           140601  Dallam  Rita Blanca            6         19        1989
#
#    SampleDate  SampleTime SampleTimeZone  SampleNumber  ... SampleBU  \
# 0  1989-06-19      1818.0            NaN             1  ...        B
# 1  1989-06-19      1818.0            NaN             1  ...        B
# ...
