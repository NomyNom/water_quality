# %%
import numpy as np
import pandas as pd

# %%
station_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/station.csv')
station_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 station_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/station.csv')
# ----> 2 station_df.head(station_df)
#
# File ~/Library/Python/3.12/lib/python/site-packages/pandas/core/generic.py:5893, in NDFrame.head(self, n)
#    5891 if using_copy_on_write():
#    5892     return self.iloc[:n].copy()
# -> 5893 return self.iloc[:n]
#
# File ~/Library/Python/3.12/lib/python/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...
