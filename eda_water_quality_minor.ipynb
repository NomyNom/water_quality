# %%
import numpy as np
import pandas as pd
import sys
from util.convertfile import *

# %%
def print_full(df):
    pd.set_option('display.max_rows', len(df))
    print(df)
    pd.reset_option('display.max_rows')

# %%
water_quality_minor_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/WaterQualityMinor_v1.csv')
water_quality_minor_df.head()
# Out:
# /var/folders/jw/plp7h3rx77nby1bttx42xypw0000gn/T/ipykernel_56916/3702369995.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   water_quality_minor_df = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/WaterQualityMinor_v1.csv')
#    StateWellNumber  County      Aquifer  SampleMonth  SampleDay  SampleYear  \
# 0           140601  Dallam  Rita Blanca            6         19        1989
# 1           140601  Dallam  Rita Blanca            6         19        1989
# 2           140601  Dallam  Rita Blanca            6         19        1989
# 3           140601  Dallam  Rita Blanca            6         19        1989
# 4           140601  Dallam  Rita Blanca            6         19        1989
#
#    SampleDate  SampleTime SampleTimeZone  SampleNumber  ... SampleBU  \
# 0  1989-06-19      1818.0            NaN             1  ...        B
# 1  1989-06-19      1818.0            NaN             1  ...        B
# ...

# %%
water_quality_minor_df.columns
# Out:
# Index(['StateWellNumber', 'County', 'Aquifer', 'SampleMonth', 'SampleDay',
#        'SampleYear', 'SampleDate', 'SampleTime', 'SampleTimeZone',
#        'SampleNumber', 'Reliability', 'CollectionEntity', 'AnalyzedLab',
#        'SampledAquifer', 'SampleTopInterval', 'SampleBottomInterval',
#        'CollectionRemarks', 'SampleBU', 'SampleBUValue', 'ParameterCode',
#        'ParameterDescription', 'ParameterUnitOfMeasure', 'ParameterFlag',
#        'ParameterValue', 'ParameterValuePlusMinus', 'CreatedDate',
#        'LastUpdateDate'],
#       dtype='object')

# %%
filtered_county_df = water_quality_minor_df[water_quality_minor_df['County'] == 'Dallam']
filtered_county_df
# Out:
#       StateWellNumber  County      Aquifer  SampleMonth  SampleDay  \
# 0              140601  Dallam  Rita Blanca            6         19
# 1              140601  Dallam  Rita Blanca            6         19
# 2              140601  Dallam  Rita Blanca            6         19
# 3              140601  Dallam  Rita Blanca            6         19
# 4              140601  Dallam  Rita Blanca            6         19
# ...               ...     ...          ...          ...        ...
# 2799           250101  Dallam  Rita Blanca            8          2
# 2800           250101  Dallam  Rita Blanca            8          2
# 2801           250101  Dallam  Rita Blanca            8          2
# 2802           250101  Dallam  Rita Blanca            8          2
# 2803           250101  Dallam  Rita Blanca            8          2
#
#       SampleYear  SampleDate  SampleTime SampleTimeZone  SampleNumber  ...  \
# 0           1989  1989-06-19      1818.0            NaN             1  ...
# ...

# %%
# print(filtered_county_df['ParameterDescription'])
print_full(filtered_county_df['ParameterDescription'])
# Out:
# 0                      ALKALINITY, PHENOLPHTHALEIN (MG/L)
# 1                       ALKALINITY, TOTAL (MG/L AS CACO3)
# 2                        ALUMINUM, DISSOLVED (UG/L AS AL)
# 3                         ARSENIC, DISSOLVED (UG/L AS AS)
# 4                          BARIUM, DISSOLVED (UG/L AS BA)
# 5              BICARBONATE ION, CALCULATED (MG/L AS HCO3)
# 6                            BORON, DISSOLVED (UG/L AS B)
# 7                         CADMIUM, DISSOLVED (UG/L AS CD)
# 8                         CALCIUM, DISSOLVED (MG/L AS CA)
# 9                 CARBONATE ION, CALCULATED (MG/L AS CO3)
# 10                       CHLORIDE, DISSOLVED (MG/L AS CL)
# 11                       CHROMIUM, DISSOLVED (UG/L AS CR)
# 12                         COPPER, DISSOLVED (UG/L AS CU)
# 13                        FLUORIDE, DISSOLVED (MG/L AS F)
# 14            HARDNESS, TOTAL, CALCULATED (MG/L AS CACO3)
# 15                           IRON, DISSOLVED (UG/L AS FE)
# ...

# %%
print(water_quality_minor_df['County'].unique())
# Out:
# ['Dallam' 'Wheeler' 'Collingsworth' 'Potter' 'Randall' 'Armstrong'
#  'Hartley' 'Moore' 'Oldham' 'Deaf Smith' 'Castro' 'Swisher' 'Briscoe'
#  'Floyd' 'Hale' 'Motley' 'Childress' 'Cottle' 'Hardeman' 'Foard' 'Wichita'
#  'Clay' 'Red River' 'Bowie' 'Cass' 'Morris' 'Lamar' 'Fannin' 'Hunt'
#  'Delta' 'Hopkins' 'Grayson' 'Cooke' 'Denton' 'Collin' 'Montague' 'Jack'
#  'Wise' 'Archer' 'Young' 'Parker' 'Throckmorton' 'Baylor' 'Dickens' 'King'
#  'Stonewall' 'Crosby' 'Lubbock' 'Garza' 'Lynn' 'Kent' 'Lamb' 'Hockley'
#  'Cochran' 'Yoakum' 'Terry' 'Gaines' 'Dawson' 'Andrews' 'Martin' 'Winkler'
#  'Scurry' 'Borden' 'Howard' 'Mitchell' 'Sterling' 'Jones' 'Fisher' 'Nolan'
#  'Shackelford' 'Taylor' 'Callahan' 'Eastland' 'Coleman' 'Brown' 'Stephens'
#  'Palo Pinto' 'Erath' 'Comanche' 'Tarrant' 'Dallas' 'Johnson' 'Ellis'
#  'Hill' 'Rockwall' 'Kaufman' 'Navarro' 'Henderson' 'Franklin' 'Wood'
#  'Upshur' 'Van Zandt' 'Smith' 'Cherokee' 'Anderson' 'Camp' 'Marion'
# ...

# %%
# List of all Texas counties 
all_texas_counties = [
    "Anderson", "Andrews", "Angelina", "Aransas", "Archer", "Armstrong", "Atascosa", "Austin", "Bailey",
    "Bandera", "Bastrop", "Baylor", "Bee", "Bell", "Bexar", "Blanco", "Borden", "Bosque", "Bowie", "Brazoria",
    "Brazos", "Brewster", "Briscoe", "Brooks", "Brown", "Burleson", "Burnet", "Caldwell", "Calhoun",
    "Callahan", "Cameron", "Camp", "Carson", "Cass", "Castro", "Chambers", "Cherokee", "Childress", "Clay",
    "Cochran", "Coke", "Coleman", "Collin", "Collingsworth", "Colorado", "Comal", "Comanche", "Concho",
    "Cooke", "Coryell", "Cottle", "Crane", "Crockett", "Crosby", "Culberson", "Dallam", "Dallas", "Dawson",
    "Deaf Smith", "Delta", "Denton", "DeWitt", "Dickens", "Dimmit", "Donley", "Duval", "Eastland", "Ector",
    "Edwards", "Ellis", "El Paso", "Erath", "Falls", "Fannin", "Fayette", "Fisher", "Floyd", "Foard",
    "Fort Bend", "Franklin", "Freestone", "Frio", "Gaines", "Galveston", "Garza", "Gillespie", "Glasscock",
    "Goliad", "Gonzales", "Gray", "Grayson", "Gregg", "Grimes", "Guadalupe", "Hale", "Hall", "Hamilton",
    "Hansford", "Hardeman", "Hardin", "Harris", "Harrison", "Hartley", "Haskell", "Hays", "Hemphill",
    "Henderson", "Hidalgo", "Hill", "Hockley", "Hood", "Hopkins", "Houston", "Howard", "Hudspeth", "Hunt",
    "Hutchinson", "Irion", "Jack", "Jackson", "Jasper", "Jeff Davis", "Jefferson", "Jim Hogg", "Jim Wells",
    "Johnson", "Jones", "Karnes", "Kaufman", "Kendall", "Kenedy", "Kent", "Kerr", "Kimble", "King", "Kinney",
    "Kleberg", "Knox", "Lamar", "Lamb", "Lampasas", "La Salle", "Lavaca", "Lee", "Leon", "Liberty",
    "Limestone", "Lipscomb", "Live Oak", "Llano", "Loving", "Lubbock", "Lynn", "McCulloch", "McLennan",
    "McMullen", "Madison", "Marion", "Martin", "Mason", "Matagorda", "Maverick", "Medina", "Menard",
    "Midland", "Milam", "Mills", "Mitchell", "Montague", "Montgomery", "Moore", "Morris", "Motley",
    "Nacogdoches", "Navarro", "Newton", "Nolan", "Nueces", "Ochiltree", "Oldham", "Orange", "Palo Pinto",
    "Panola", "Parker", "Parmer", "Pecos", "Polk", "Potter", "Presidio", "Rains", "Randall", "Reagan",
    "Real", "Red River", "Reeves", "Refugio", "Roberts", "Robertson", "Rockwall", "Runnels", "Rusk",
    "Sabine", "San Augustine", "San Jacinto", "San Patricio", "San Saba", "Schleicher", "Scurry",
    "Shackelford", "Shelby", "Sherman", "Smith", "Somervell", "Starr", "Stephens", "Sterling", "Stonewall",
    "Sutton", "Swisher", "Tarrant", "Taylor", "Terrell", "Terry", "Throckmorton", "Titus", "Tom Green",
    "Travis", "Trinity", "Tyler", "Upshur", "Upton", "Uvalde", "Val Verde", "Van Zandt", "Victoria",
    "Walker", "Waller", "Ward", "Washington", "Webb", "Wharton", "Wheeler", "Wichita", "Wilbarger",
    "Willacy", "Williamson", "Wilson", "Winkler", "Wise", "Wood", "Yoakum", "Young", "Zapata", "Zavala"
]

# List from the water quality minor
provided_counties = [
    "Dallam", "Wheeler", "Collingsworth", "Potter", "Randall", "Armstrong",
    "Hartley", "Moore", "Oldham", "Deaf Smith", "Castro", "Swisher", "Briscoe",
    "Floyd", "Hale", "Motley", "Childress", "Cottle", "Hardeman", "Foard", "Wichita",
    "Clay", "Red River", "Bowie", "Cass", "Morris", "Lamar", "Fannin", "Hunt",
    "Delta", "Hopkins", "Grayson", "Cooke", "Denton", "Collin", "Montague", "Jack",
    "Wise", "Archer", "Young", "Parker", "Throckmorton", "Baylor", "Dickens", "King",
    "Stonewall", "Crosby", "Lubbock", "Garza", "Lynn", "Kent", "Lamb", "Hockley",
    "Cochran", "Yoakum", "Terry", "Gaines", "Dawson", "Andrews", "Martin", "Winkler",
    "Scurry", "Borden", "Howard", "Mitchell", "Sterling", "Jones", "Fisher", "Nolan",
    "Shackelford", "Taylor", "Callahan", "Eastland", "Coleman", "Brown", "Stephens",
    "Palo Pinto", "Erath", "Comanche", "Tarrant", "Dallas", "Johnson", "Ellis",
    "Hill", "Rockwall", "Kaufman", "Navarro", "Henderson", "Franklin", "Wood",
    "Upshur", "Van Zandt", "Smith", "Cherokee", "Anderson", "Camp", "Marion",
    "Harrison", "Gregg", "Sabine", "Jasper", "Rusk", "Nacogdoches", "Angelina",
    "San Augustine", "Trinity", "Polk", "Tyler", "Freestone", "Leon", "Houston",
    "Madison", "Walker", "Falls", "Robertson", "Milam", "Bosque", "McLennan",
    "Mills", "San Saba", "Lampasas", "Burnet", "Runnels", "Concho", "McCulloch",
    "Menard", "Tom Green", "Irion", "Midland", "Glasscock", "Upton", "Reagan",
    "Crockett", "Ector", "Crane", "Ward", "Pecos", "Loving", "Reeves", "Culberson",
    "Hudspeth", "Jeff Davis", "Presidio", "Brewster", "Mason", "Kimble",
    "Gillespie", "Kerr", "Llano", "Blanco", "Lee", "Bastrop", "Fayette", "Brazos",
    "Grimes", "Burleson", "Washington", "Waller", "Austin", "Liberty", "Fort Bend",
    "Caldwell", "Gonzales", "Lavaca", "Wilson", "Karnes", "Atascosa", "Frio",
    "La Salle", "Live Oak", "McMullen", "Webb", "Zapata", "Starr"
]

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

missing_counties_water_quality_minor = list(set(all_texas_counties) - set(provided_counties))
df_missing_counties_water_quality_minor = pd.DataFrame(missing_counties_water_quality_minor, columns=["Missing Counties"])
df_missing_counties_water_quality_minor
# Out:
#    Missing Counties
# 0            Kenedy
# 1           Calhoun
# 2              Gray
# 3            Orange
# 4      San Patricio
# 5             Rains
# 6              Knox
# 7              Bell
# 8            Parmer
# 9             Comal
# 10           Travis
# 11          El Paso
# 12         Jim Hogg
# 13             Hays
# 14           Brooks
# 15          Hidalgo
# 16        Matagorda
# 17        Jim Wells
# 18         Lipscomb
# 19        Somervell
# 20          Coryell
# 21           Zavala
# 22          Edwards
# 23           Harris
# 24           Medina
# 25          Wharton
# 26           Uvalde
# 27          Terrell
# 28         Hamilton
# 29          Kleberg
# 30         Hansford
# 31          Jackson
# 32           Donley
# 33         Maverick
# 34          Willacy
# 35        Limestone
# 36         Hemphill
# 37         Victoria
# 38           Dimmit
# 39           Kinney
# 40       Schleicher
# 41          Roberts
# 42         Chambers
# 43             Coke
# ...
