# %%
import numpy as np
import pandas as pd
import sys
from util.convertfile import *

# %%
txt_path = "~/Documents/UH/hon4350/water_quality/GWDBDownload/GWDBDownload_data/WaterQualityMajor.txt"
csv_path = "~/Documents/UH/hon4350/water_quality/data/WaterQualityMajor_v1.csv"
txt_to_csv(txt_path, csv_path)
# Out:
# Conversion completed! CSV file saved as: /Users/minhnguyen/Documents/UH/hon4350/water_quality/data/WaterQualityMajor_v1.csv

# %%
pd.set_option('display.max_columns', None)
major_df = pd.read_csv(csv_path)
major_df
# Out:
# /var/folders/jw/plp7h3rx77nby1bttx42xypw0000gn/T/ipykernel_25964/2451287216.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   major_df = pd.read_csv(csv_path)
#          StateWellNumber   County     Aquifer  SampleMonth  SampleDay  \
# 0                 148904   Dallam    Ogallala            9         18
# 1                 148904   Dallam    Ogallala            9         18
# 2                 148904   Dallam    Ogallala            9         18
# 3                 148904   Dallam    Ogallala            9         18
# 4                 148904   Dallam    Ogallala            9         18
# ...                  ...      ...         ...          ...        ...
# 2208523          8905404  Cameron  Gulf Coast           10         17
# 2208524          8905404  Cameron  Gulf Coast           10         17
# 2208525          8905404  Cameron  Gulf Coast           10         17
# ...
