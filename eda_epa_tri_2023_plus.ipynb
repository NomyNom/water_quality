# %%
import pandas as pd
from util.convertfile import *

# %%
txt_path_1a = "~/Documents/UH/hon4350/water_quality/US_2023_epa_tri_txt/US_1a_2023.txt"
csv_path_1a = "~/Documents/UH/hon4350/water_quality/data/US_1a_2023.csv"
txt_to_csv(txt_path_1a, csv_path_1a)

txt_path_1b = "~/Documents/UH/hon4350/water_quality/US_2023_epa_tri_txt/US_1b_2023.txt"
csv_path_1b = "~/Documents/UH/hon4350/water_quality/data/US_1b_2023.csv"
txt_to_csv(txt_path_1b, csv_path_1b)
# Out:
# Conversion completed! CSV file saved as: /Users/minhnguyen/Documents/UH/hon4350/water_quality/data/US_1a_2023.csv
# Conversion completed! CSV file saved as: /Users/minhnguyen/Documents/UH/hon4350/water_quality/data/US_1b_2023.csv

# %%
pd.set_option('display.max_columns', None)

# %%
df_1a = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/US_1a_2023.csv')
df_1a
# Out:
# /var/folders/jw/plp7h3rx77nby1bttx42xypw0000gn/T/ipykernel_40474/1280427620.py:1: DtypeWarning: Columns (1,16,22,31,49,52,53,54,55,56,57,63,64,65,69,71,74,77,81,90,115,126,130,134,136,140,142,146,148,152,154,158,160,164,166,170,179,183,185,192,194,196,200,210,212,216,271,272,273) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1a = pd.read_csv('~/Documents/UH/hon4350/water_quality/data/US_1a_2023.csv')
#       1. FORM TYPE 2. REPORTING YEAR 3. TRADE SECRET INDICATOR  \
# 0                R        2023    NO                        NO
# 1                R              2023                        NO
# 2                R              2023                        NO
# 3                R              2023                        NO
# 4                A              2023                        NO
# ...            ...               ...                       ...
# 77959            A              2023                        NO
# ...
